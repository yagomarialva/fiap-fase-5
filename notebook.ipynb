# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="-")
project = rf.workspace("yolo-bqcvg").project("danger-z0lpf")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to danger-5 in yolov8:: 100%|██████████| 13878/13878 [00:02<00:00, 5487.18it/s]

# %%
# !pip install ultralytics

from ultralytics import YOLO
import os

dataset_dir = '/content/danger-5'
if not os.path.exists(dataset_dir):
    print(f"A pasta {dataset_dir} não foi encontrada.")
    print("Por favor, rode o código de download do Roboflow novamente antes deste passo.")
else:
    print("Iniciando o treinamento...")

    model = YOLO('yolov8n.pt')

    model.train(data=f'{dataset_dir}/data.yaml', epochs=20, imgsz=640)
# Out:
# ...
# ✅ Dataset encontrado! Iniciando o treinamento...
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
